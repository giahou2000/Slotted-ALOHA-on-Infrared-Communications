# %% [markdown]
# # Particle Swarm Optimization algorithm for an energy efficient configuration of an intra-OWBAN (Optical Wireless Body Area Network)

# %% [markdown]
# OWBAN explanation...

# %%
# Import modules
import matplotlib.pyplot as plt
from IPython.display import Image

# Import PySwarms
import pyswarms as ps
from pyswarms.utils.functions import single_obj as fx
from pyswarms.utils.plotters import (plot_cost_history, plot_contour, plot_surface)

# import modules
import numpy as np

# %%
# create a parameterized objective function to calculate the energy efficiency of the configurations of the network
def obj_func(x, a, b):
    f = 5
    return (-f)

# %%
from pyswarms.single.global_best import GlobalBestPSO

# instatiate the optimizer
iterations = 1000
x_max = np.array([0.5, 30, 5])
x_min = np.array([1, 60, 10])
bounds = (x_min, x_max)
options = {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
optimizer = GlobalBestPSO(n_particles=50, dimensions=3, options=options, bounds=bounds)

# %%
# now run the optimization

kwargs={"a": 1.0, "b": 100.0}
cost, pos = optimizer.optimize(obj_func, iterations, **kwargs)

plot_cost_history(cost_history=optimizer.cost_history)
plt.show()
# Out:
# 2024-09-12 11:53:18,201 - pyswarms.single.global_best - INFO - Optimize for 1000 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|██████████|1000/1000, best_cost=-5
# 2024-09-12 11:53:19,122 - pyswarms.single.global_best - INFO - Optimization finished | best cost: -5.0, best pos: [ 0.76881302 35.06327036  8.58150856]
